# %% [markdown]
# # In-Class Assignment: Building a Small AI Coding Pipeline
#
# ## Behavioral Data Science
#
# In this assignment, you will apply the ideas from the pre-class tutorial. Your goal is to use a large language model to convert short open-ended responses into structured data that you can analyze in Python.
#
# This assignment is designed to be completed in **one class period**. Work carefully, keep your code simple, and test each step before moving to the next one.
#
# ## Learning goals
#
# By the end of this assignment, you should be able to:
#
# 1. Send repeated prompts to a language model using Python.
# 2. Ask the model for structured output.
# 3. Build a Pandas DataFrame from model responses.
# 4. Compute a few simple descriptive statistics.
# 5. Reflect on how prompt design shapes the resulting dataset.

# %% [markdown]
# ## Part 0. Environment and package check
#
# Run the next two cells first. They will help verify that your notebook is running in the expected Python environment and that the required packages are installed.

# %%
import sys
import subprocess
import importlib

def install_if_missing(package_name, import_name=None):
    if import_name is None:
        import_name = package_name
    try:
        importlib.import_module(import_name)
        print(f"{package_name} is already installed.")
    except ImportError:
        print(f"{package_name} not found. Installing now...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])

required_packages = [
    ("openai", "openai"),
    ("pandas", "pandas"),
    ("matplotlib", "matplotlib")
]

for package_name, import_name in required_packages:
    install_if_missing(package_name, import_name)

# %%
import sys
print("Python executable being used by this notebook:")
print(sys.executable)

# %% [markdown]
# ## Scenario
#
# Imagine that you are working with short student reflections collected after a stressful academic week. You want to use AI to help code the responses into a few simple variables that can be analyzed quantitatively.
#
# For each response, your AI system should identify:
#
# - **emotion**: a short category such as stress, anxiety, joy, confusion, pride, calm, frustration, sadness, or neutral
# - **valence**: positive, negative, or neutral
# - **intensity**: an integer from 1 to 5
#
# Your task is to create a small dataset from these responses and summarize the results.

# %% [markdown]
# ## Part 1. Import packages and connect to the API
#
# Run the next cell. If the connection fails, revisit the setup from the tutorial.

# %%
import os
import json
import time
import pandas as pd
import matplotlib.pyplot as plt

from openai import OpenAI

api_key = os.getenv("OPENAI_API_KEY")

if api_key is None:
    raise ValueError("OPENAI_API_KEY was not found. Please make sure it is stored as an environment variable.")

client = OpenAI(api_key=api_key)
print("Client created successfully.")

# %% [markdown]
# ## Part 2. The responses to analyze
#
# These are short synthetic responses created for teaching purposes.
#
# To keep the assignment manageable within one hour and reduce the chance of rate-limit errors, the dataset is intentionally small.

# %%
responses = [
    "I am exhausted and still have three assignments left.",
    "I feel pretty good because I finally understand the material.",
    "I am confused about what the professor wants in the paper.",
    "I am stressed because everything is due at the same time.",
    "I feel calm now that I made a schedule for the week."
]

pd.DataFrame({"response_text": responses})

# %% [markdown]
# ## Part 3. Inspect one response manually
#
# Before automating the full task, begin with a single example. This is good scientific and programming practice.

# %%
example_text = responses[0]
print(example_text)

# %% [markdown]
# ### Task 1
#
# Write code in the next cell to ask the model to classify the example response.
#
# Your instructions to the model should request **JSON output** with exactly these keys:
#
# - `"emotion"`
# - `"valence"`
# - `"intensity"`
#
# Additional rules:
#
# - `"emotion"` should be one short category.
# - `"valence"` should be one of: positive, negative, neutral.
# - `"intensity"` should be an integer from 1 to 5.
# - The model should return **JSON only**.
#
# After you run the cell, print the raw model output.

# %%
# Write your code here

# %% [markdown]
# ### Task 2
#
# Convert the model's JSON text into a Python dictionary using `json.loads()`. Then display the dictionary.
#
# If JSON parsing fails, print the raw output and inspect whether there is extra text before or after the JSON object.

# %%
# Write your code here

# %% [markdown]
# ## Part 4. Create a reusable function
#
# Now write a function called `code_response()` that takes one argument, `text`, and returns a Python dictionary with the three fields:
#
# - emotion
# - valence
# - intensity
#
# Use the same JSON-based prompt style from Part 3.
#
# Try to include simple error handling:
# - if JSON parsing fails, print the raw output
# - if parsing still fails, return `None` values

# %%
# Write your function here

# %% [markdown]
# ### Check your function
#
# Run your function on the second response in the list. If it does not work yet, fix it before moving on.

# %%
# Test your function here

# %% [markdown]
# ## Part 5. Use a loop to code all responses
#
# Now create an empty list called `coded_results`. Then loop over all responses and apply your function to each one.
#
# For each response:
#
# 1. call your function
# 2. save the result in a dictionary
# 3. add the original text under the key `"response_text"`
# 4. append that dictionary to `coded_results`
#
# To reduce the chance of rate-limit errors, add a short pause such as `time.sleep(1)` inside the loop.

# %%
# Write your loop here

# %% [markdown]
# ### Check your work
#
# Display the first two elements of `coded_results`.

# %%
# Display your results here

# %% [markdown]
# ## Part 6. Build a DataFrame
#
# Convert `coded_results` into a Pandas DataFrame named `df`.

# %%
# Create your DataFrame here

# %% [markdown]
# ### Inspect the dataset
#
# Display:
#
# 1. the DataFrame
# 2. the column names
# 3. the data types

# %%
# Inspect your DataFrame here

# %% [markdown]
# ## Part 7. Descriptive analysis
#
# Now answer the following questions with code.
#
# ### Task 3
# How many times does each emotion category appear?

# %%
# Write your code here

# %% [markdown]
# ### Task 4
# What is the average intensity score?

# %%
# Write your code here

# %% [markdown]
# ### Task 5
# Create a simple bar plot showing the count of each emotion category.

# %%
# Write your code here

# %% [markdown]
# ## Part 8. Short interpretation
#
# In the markdown cell below, write **3 to 5 sentences** answering the following:
#
# 1. Which emotional categories appeared most often?
# 2. Was the overall intensity high, low, or moderate?
# 3. Do you think the AI coding seems reasonable?
# 4. What is one limitation of using AI in this way?
#
# Replace the placeholder text with your response.

# %% [markdown]
# _Write your interpretation here._

# %% [markdown]
# ## Part 9. Optional extension if you finish early
#
# Choose **one** of the following:
#
# ### Option A
# Add a fourth variable called `"confidence"` with values from 1 to 5.
#
# ### Option B
# Change the prompt so that the model uses a smaller emotion set:
# - positive
# - negative
# - neutral
#
# Then compare how the results differ from your first dataset.
#
# ### Option C
# Add two new responses of your own and run the pipeline again.

# %% [markdown]
# ## Submission checklist
#
# Before you submit, make sure that:
#
# - your notebook runs from top to bottom
# - your function works
# - your DataFrame was created successfully
# - you answered the interpretation questions
# - your code is readable

# %% [markdown]
# ## Instructor note
#
# This assignment is intentionally simple. The main goal is not to build a perfect classifier, but to practice turning natural language into structured data using a reproducible workflow.
#
# If you encounter a `RateLimitError`, wait a few seconds and try again. If you encounter a `JSONDecodeError`, print the raw model output and inspect whether it contains extra text.
